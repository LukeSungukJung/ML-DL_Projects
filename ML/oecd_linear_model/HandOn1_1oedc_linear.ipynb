# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn.linear_model
import warnings
warnings.filterwarnings('ignore')

# %%
oecd_bli = pd.read_csv('2015_oecd_bli.csv',thousands=',')
oecd_bli.head()
# Out:
#      Country    Dwellings without basic facilities    Housing expenditure  \
# 0  Australia                                   1.1                     20
# 1    Austria                                   1.0                     21
# 2    Belgium                                   2.0                     21
# 3     Canada                                   0.2                     21
# 4      Chile                                   9.4                     18
#
#      Rooms per person    Household net adjusted disposable income  \
# 0                 2.3                                       31588
# 1                 1.6                                       31173
# 2                 2.2                                       28307
# 3                 2.5                                       29365
# 4                 1.2                                       14533
#
#      Household net financial wealth    Employment rate    Job security  \
# ...

# %%
oecd_bli.isnull().sum()
# Out:
# Country                                        0
#   Dwellings without basic facilities           0
#   Housing expenditure                          0
#   Rooms per person                             0
#   Household net adjusted disposable income     0
#   Household net financial wealth               0
#   Employment rate                              0
#   Job security                                 0
#   Long-term unemployment rate                  0
#   Personal earnings                            0
#   Quality of support network                   0
#   Educational attainment                       0
#   Student skills                               0
#   Years in education                           0
#   Air pollution                                0
#   Water quality                                0
#   Consultation on rule-making                  0
#   Voter turnout                                0
#   Life expectancy                              0
# ...

# %%
oecd_bli.describe()
# Out:
#          Dwellings without basic facilities    Housing expenditure  \
# count                             36.000000              36.000000
# mean                               2.533333              20.833333
# std                                3.750581               2.843539
# min                                0.000000              11.000000
# 25%                                0.200000              19.750000
# 50%                                0.800000              21.000000
# 75%                                3.825000              22.000000
# max                               15.100000              26.000000
#
#          Rooms per person    Household net adjusted disposable income  \
# count           36.000000                                   36.000000
# mean             1.661111                                24121.722222
# std              0.432453                                 7273.211307
# min              0.900000                                11664.000000
# ...

# %%
life_satisfaction = oecd_bli['  Life satisfaction']
earnings = oecd_bli['  Personal earnings']

# %%
y=np.c_[life_satisfaction]
x=np.c_[earnings]

# %%
plt.scatter(x,y,marker='*',c='g')
plt.grid(True)
plt.show()

# %%
#y= x*w0+ w1

# %%
model = sklearn.linear_model.LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
x_new=[[22587]]

# %%
print(model.predict(x_new))
# Out:
# [[6.04493715]]

# %%
x_v2= [earnings,oecd_bli['  Household net adjusted disposable income']]

# %%
#y= x*w0 +w1*x2+w2

# %%
import seaborn as sns
fig,ax = plt.subplots(1,3,figsize=(25,7))
sns.scatterplot(x="  Personal earnings", y="  Life satisfaction", data=oecd_bli,ax=ax[0])
sns.scatterplot(x='  Household net adjusted disposable income', y="  Life satisfaction", data=oecd_bli,ax=ax[1])
sns.scatterplot(x='  Household net adjusted disposable income', y="  Life satisfaction", data=oecd_bli,ax=ax[2])
sns.scatterplot(x="  Personal earnings", y="  Life satisfaction", data=oecd_bli,ax=ax[2])

# %%
model.fit(oecd_bli[['  Personal earnings','  Household net adjusted disposable income']],oecd_bli['  Life satisfaction'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(model.predict([[35981,31412]]))
# Out:
# [6.50580339]

# %%
import sklearn.neighbors
knl_model = sklearn.neighbors.KNeighborsRegressor(n_neighbors=3)
knl_model.fit(x,y)
print(knl_model.predict(x_new))
# Out:
# [[5.86666667]]

# %%
x_new
# Out:
# [[22587]]

# %% [markdown]
# <h2>Second Chellange</h2>

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.distplot(oecd_bli['  Life satisfaction'])

# %%
from scipy import stats
fig = plt.figure(figsize=(15,10))

fig.add_subplot(1,3,1)
res = stats.probplot(oecd_bli['  Life satisfaction'],plot=plt)

fig.add_subplot(1,3,3)
res = stats.probplot(np.sinh(oecd_bli['  Life satisfaction']),plot=plt)

fig.add_subplot(1,3,2)
res = stats.probplot(np.log1p(oecd_bli['  Life satisfaction']),plot=plt)

# %%
fig.add_subplot(1,1,1)
res =sns.distplot(oecd_bli['  Life satisfaction'])

# %%
fig.add_subplot(1,3,2)
res =sns.distplot(np.sinh(oecd_bli['  Life satisfaction']))

# %%
fig.add_subplot(1,3,3)
res =sns.distplot(np.log1p(oecd_bli['  Life satisfaction']))

# %%
import scipy as sp

cor_abs = abs(oecd_bli.corr(method='spearman'))
cor_cols = cor_abs.nlargest(n=24, columns="  Life satisfaction").index
#df_train =  oecd_bli
#df_train['  Life satisfaction']=np.tan(df_train['  Life satisfaction'])

# %%
cor = np.array(sp.stats.spearmanr(oecd_bli[cor_cols].values))[0]
plt.figure(figsize=(15,15))
sns.set(font_scale=1)
sns.heatmap(cor,fmt='.2f', annot=True, square=True, annot_kws={'size': 8}, xticklabels=cor_cols.values,yticklabels=cor_cols.values)

# %%
black_blocks = [' Long-term unemployment rate','  Dwellings without basic facilities','  Homicide rate']

# %%
data = pd.concat([oecd_bli["  Life satisfaction"],oecd_bli["  Employment rate"]], axis=1)
data['  Employment rate']=np.log1p(data['  Employment rate'])

# %%
f, ax = plt.subplots(figsize=(10,8))
fig = sns.barplot(x="  Employment rate",y="  Life satisfaction", data=data)

# %%
f, ax = plt.subplots(figsize=(10,8))
data = pd.concat([oecd_bli["  Life satisfaction"],oecd_bli["  Personal earnings"]], axis=1)
data["  Personal earnings"]=-np.cos(data["  Personal earnings"])+np.sin(data["  Personal earnings"])
fig = sns.scatterplot(x="  Personal earnings",y="  Life satisfaction", data=data)

# %%
data = pd.concat([oecd_bli["  Life satisfaction"],oecd_bli["  Homicide rate"]], axis=1)
data["  Homicide rate"]=np.log1p(data["  Homicide rate"])
oecd_bli["  Homicide rate"] =np.log1p(oecd_bli["  Homicide rate"])
oecd_bli["  Employment rate"] =np.log1p(oecd_bli["  Employment rate"])
oecd_bli["  Homicide rate"] =np.log1p(oecd_bli["  Homicide rate"])
oecd_bli["  Household net adjusted disposable income"] =oecd_bli["  Household net adjusted disposable income"]/np.max(oecd_bli["  Household net adjusted disposable income"])
oecd_bli["  Long-term unemployment rate"] =(oecd_bli["  Long-term unemployment rate"])/np.max(oecd_bli["  Long-term unemployment rate"])
oecd_bli["  Household net financial wealth"]=np.cos(oecd_bli["  Household net financial wealth"])-np.sin(oecd_bli["  Household net financial wealth"])
oecd_bli["  Personal earnings"]=-np.cos(oecd_bli["  Personal earnings"])+np.sin(oecd_bli["  Personal earnings"])

# %%
#y = oecd_bli['  Life satisfaction'].
#oecd_bli.drop(['  Life satisfaction'])
y =np.array(oecd_bli['  Life satisfaction'])
oecd_bli.drop(['  Life satisfaction'], axis=1, inplace = True)

# %%
oecd_bli.drop(['Country'], axis=1, inplace = True)

# %%
model.fit(oecd_bli,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.predict(oecd_bli)[1]
# Out:
# 6.905881914026104
